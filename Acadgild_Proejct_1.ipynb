# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt   # importing packages recquired to develop this project

# %%
#read the following two CSV and read them into df and df1

# %%
df=pd.read_csv('https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv')
df.head(2)
# Out:
#                           Indicator PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
df1=pd.read_csv('https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv')
df1.head(2)
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
#
#    TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
#
# [2 rows x 21 columns]

# %%
# Q1 Get the metadata from the above files

# %%
df.info() #using the info method provide us the metadata information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
# Indicator                  4656 non-null object
# PUBLISH STATES             4656 non-null object
# Year                       4656 non-null int64
# WHO region                 4656 non-null object
# World Bank income group    4656 non-null object
# Country                    4656 non-null object
# Sex                        4656 non-null object
# Display Value              4656 non-null int64
# Numeric                    4656 non-null float64
# Low                        0 non-null float64
# High                       0 non-null float64
# Comments                   0 non-null float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
# STATION         117208 non-null object
# STATION_NAME    117208 non-null object
# DATE            117208 non-null int64
# PRCP            117208 non-null int64
# SNWD            117208 non-null int64
# SNOW            117208 non-null int64
# TMAX            117208 non-null int64
# TMIN            117208 non-null int64
# WDFG            117208 non-null int64
# PGTM            117208 non-null int64
# WSFG            117208 non-null int64
# WT09            117208 non-null int64
# WT07            117208 non-null int64
# WT01            117208 non-null int64
# WT06            117208 non-null int64
# WT05            117208 non-null int64
# WT04            117208 non-null int64
# WT16            117208 non-null int64
# WT08            117208 non-null int64
# WT18            117208 non-null int64
# WT03            117208 non-null int64
# dtypes: int64(19), object(2)
# ...

# %%
# Q2 Get the row names from the above files.

# %%
np.array((df.index)) #df.index gives the row names which we than passed into numpy array to get the output asked in question
# Out:
# array([   0,    1,    2, ..., 4653, 4654, 4655], dtype=int64)

# %%
np.array((df1.index))
# Out:
# array([     0,      1,      2, ..., 117205, 117206, 117207], dtype=int64)

# %%
# Q3 Change the column name from any of the above file.

# %%
#we will renaming the indicator columns in to indicator_id

# %%
df.rename(columns={'Indicator':'Indicator_id'}) # we can  also use the axis =colmns method
df.head(2)
# Out:
#                           Indicator PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
# Q4 Change the column name from any of the above file and store the changes made
#  permanently.

# %%
# this Question is similar to question 3 but to make changes permanetly we have to use the inplace=True

# %%
df.rename({'Indicator':'Indicator_id'}, axis=1, inplace=True)

# %%
df.head(2) #
# Out:
#                        Indicator_id PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
# Q5 Change the names of multiple columns.

# %%
#For Dataframe df
df.rename(columns={'PUBLISH STATES':'Publication Status','WHO region':'WHO Region'},inplace=True) #Using Inplace=True To make changes Permanently
df.head(2)
# Out:
#                        Indicator_id Publication Status  Year WHO Region  \
# 0  Life expectancy at birth (years)          Published  1990     Europe
# 1  Life expectancy at birth (years)          Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
#for df1
df1.rename(columns={'STATION':'STATION_Id','DATE':'Year'},inplace=True) #Using Inplace=True To make changes Permanently
df1.head(2)
# Out:
#           STATION_Id         STATION_NAME      Year  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
#
#    TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
#
# [2 rows x 21 columns]

# %%
#Q6  Arrange values of a particular column in ascending order.

# %%
#for df
df.sort_values('Year',ascending=True)[0:4] #Arrange the value of Column "Year"
# Out:
#                           Indicator_id Publication Status  Year WHO Region  \
# 0     Life expectancy at birth (years)          Published  1990     Europe
# 1270  Life expectancy at birth (years)          Published  1990     Europe
# 3193  Life expectancy at birth (years)          Published  1990     Europe
# 3194  Life expectancy at birth (years)          Published  1990     Europe
#
#      World Bank income group              Country         Sex  Display Value  \
# 0                High-income              Andorra  Both sexes             77
# 1270             High-income              Germany        Male             72
# 3193     Lower-middle-income  Republic of Moldova        Male             65
# 3194     Lower-middle-income  Republic of Moldova  Both sexes             68
#
#       Numeric  Low  High  Comments
# 0        77.0  NaN   NaN       NaN
# 1270     72.0  NaN   NaN       NaN
# 3193     65.0  NaN   NaN       NaN
# 3194     68.0  NaN   NaN       NaN

# %%
#For Dataframe df1
df1.sort_values('PRCP',ascending=True)[0:3] #Arrange the value of Column "PRCP"
# Out:
#                STATION_Id     STATION_NAME      Year  PRCP  SNWD  SNOW  TMAX  \
# 96354   GHCND:GME00121150  BERLIN TEGEL GM  19390609 -9999 -9999 -9999   200
# 114767  GHCND:GMM00010385    SCHONEFELD GM  19571016 -9999 -9999 -9999   150
# 114768  GHCND:GMM00010385    SCHONEFELD GM  19571017 -9999 -9999 -9999   150
#
#         TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  \
# 96354     89 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 114767    78 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 114768    78 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#         WT08  WT18  WT03
# 96354  -9999 -9999 -9999
# 114767 -9999 -9999 -9999
# 114768 -9999 -9999 -9999
#
# [3 rows x 21 columns]

# %%
# Q7 Arrange multiple column values in ascending order.

# %%
#For Dataframe df 
df.sort_values(['Year','Numeric'],ascending=True)[0:3]
# Out:
#                            Indicator_id Publication Status  Year WHO Region  \
# 1474  Life expectancy at age 60 (years)          Published  1990     Africa
# 1476  Life expectancy at age 60 (years)          Published  1990     Africa
# 1813  Life expectancy at age 60 (years)          Published  1990     Africa
#
#      World Bank income group       Country     Sex  Display Value  Numeric  \
# 1474              Low-income  Sierra Leone    Male             11     11.0
# 1476              Low-income  Sierra Leone  Female             11     11.0
# 1813              Low-income       Eritrea    Male             11     11.0
#
#       Low  High  Comments
# 1474  NaN   NaN       NaN
# 1476  NaN   NaN       NaN
# 1813  NaN   NaN       NaN

# %%
# Q8 Make country as the first column of the dataframe.

# %%
#we will first insert the column 'Country1' as the first index with its value being copied from Country 
# Column and than delete this column 
df.insert(0,'Country1',df['Country']) # inesert the 'Country1' column
df.drop('Country',axis=1)  #Drop the 'Country' Column
df.rename({'Country1':'Country'}, axis=1, inplace=True)
df.head(3)
# Out:
#    Country                       Indicator_id Publication Status  Year  \
# 0  Andorra   Life expectancy at birth (years)          Published  1990
# 1  Andorra   Life expectancy at birth (years)          Published  2000
# 2  Andorra  Life expectancy at age 60 (years)          Published  2012
#
#   WHO Region World Bank income group  Country         Sex  Display Value  \
# 0     Europe             High-income  Andorra  Both sexes             77
# 1     Europe             High-income  Andorra  Both sexes             80
# 2     Europe             High-income  Andorra      Female             28
#
#    Numeric  Low  High  Comments
# 0     77.0  NaN   NaN       NaN
# 1     80.0  NaN   NaN       NaN
# 2     28.0  NaN   NaN       NaN

# %%
# Q9 Get the column array using a variable 
# Expected Output:
# array(['Europe','Europe','Africa','Africa'],dtype=Object)

# %%
np.array(df['WHO Region']) #Data frame converted into a array
# Out:
# array(['Europe', 'Europe', 'Europe', ..., 'Africa', 'Africa', 'Africa'],
#       dtype=object)

# %%
#Q10 Get the subset rows 11, 24, 37

# %%
df.iloc[[11,24,37]]
# Out:
#               Country                       Indicator_id Publication Status  \
# 11            Austria   Life expectancy at birth (years)          Published
# 24  Brunei Darussalam  Life expectancy at age 60 (years)          Published
# 37             Cyprus  Life expectancy at age 60 (years)          Published
#
#     Year       WHO Region World Bank income group            Country     Sex  \
# 11  2012           Europe             High-income            Austria  Female
# 24  2012  Western Pacific             High-income  Brunei Darussalam  Female
# 37  2012           Europe             High-income             Cyprus  Female
#
#     Display Value  Numeric  Low  High  Comments
# 11             83     83.0  NaN   NaN       NaN
# 24             21     21.0  NaN   NaN       NaN
# 37             26     26.0  NaN   NaN       NaN

# %%
# Q11 Get the subset rows excluding 5, 12, 23, and 56 Expected Output:

# %%
# These steps will be done for both dataframe df and df1 
#For Dataframe df 
#we will drop rows 5,12,23,56 from original dataframes and than will stroe them in another dataframe

# %%
newdf=df.drop([5,12,23,56],axis=0) #drop and then stroing in another dataframe
newdf[1:60]
# Out:
#                                               Country  \
# 1                                             Andorra
# 2                                             Andorra
# 3                                             Andorra
# 4                                United Arab Emirates
# 6                                 Antigua and Barbuda
# 7                                 Antigua and Barbuda
# 8                                           Australia
# 9                                           Australia
# 10                                          Australia
# 11                                            Austria
# 13                                            Belgium
# 14                                            Bahrain
# 15                                            Bahrain
# 16                                            Bahrain
# 17                                            Bahamas
# 18                                            Bahamas
# ...

# %%
newdf1=df1.drop([5,12,23,56],axis=0) #drop and then stroing in another dataframe
newdf1[1:60]
# Out:
#            STATION_Id         STATION_NAME      Year  PRCP  SNWD  SNOW  TMAX  \
# 1   GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
# 2   GHCND:GME00111445  BERLIN TEMPELHOF GM  19310103 -9999 -9999 -9999    28
# 3   GHCND:GME00111445  BERLIN TEMPELHOF GM  19310105    13 -9999 -9999    39
# 4   GHCND:GME00111445  BERLIN TEMPELHOF GM  19310106 -9999 -9999 -9999     0
# 6   GHCND:GME00111445  BERLIN TEMPELHOF GM  19310108    13 -9999 -9999    11
# 7   GHCND:GME00111445  BERLIN TEMPELHOF GM  19310109    10 -9999 -9999   -22
# 8   GHCND:GME00111445  BERLIN TEMPELHOF GM  19310110 -9999 -9999 -9999     0
# 9   GHCND:GME00111445  BERLIN TEMPELHOF GM  19310112 -9999 -9999 -9999    22
# 10  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310113    13 -9999 -9999     0
# 11  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310114    15 -9999 -9999     0
# 13  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310116   150 -9999 -9999    50
# ...

# %%
# Now  Load the following datasets for completing the further Questions

# %%
users=pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv' )
sessions =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/sessions.csv' )
products =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv' )
transactions =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv')

# %%
users.head(2)
# Out:
#    UserID     User Gender  Registered   Cancelled
# 0       1  Charles   male  2012-12-21         NaN
# 1       2    Pedro   male  2010-08-01  2010-08-08

# %%
sessions.head(2)
# Out:
#    SessionID SessionDate  UserID
# 0          1  2010-01-05       2
# 1          2  2010-08-01       2

# %%
products.head(2)
# Out:
#    ProductID Product  Price
# 0          1       A  14.16
# 1          2       B  33.04

# %%
transactions.head(2)
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1

# %%
# Q12 Join users to transactions, keeping all rows from transactions and only matching rows
# from users (left join)

# %%
pd.merge(transactions,users,how='left') #using left join
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              1      2010-08-21     7.0          2         1       NaN
# 1              2      2011-05-26     3.0          4         1  Caroline
# 2              3      2011-06-16     3.0          3         1  Caroline
# 3              4      2012-08-26     1.0          2         3   Charles
# 4              5      2013-06-06     2.0          4         1     Pedro
# 5              6      2013-12-23     2.0          5         6     Pedro
# 6              7      2013-12-30     3.0          4         1  Caroline
# 7              8      2014-04-24     NaN          2         3       NaN
# 8              9      2015-04-24     7.0          4         3       NaN
# 9             10      2016-05-08     3.0          4         4  Caroline
#
#    Gender  Registered   Cancelled
# 0     NaN         NaN         NaN
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3    male  2012-12-21         NaN
# ...

# %%
# Q13. Which transactions have a UserID not in users?

# %%
#This can be solved by using the  left outer join as it will give nan for all non matching rows from the user table  
# or better approach is to use isin method

# %%
# 1 st approach 
# pd.merge(transactions,users,how='left') #using left join 
# or 2nd Approach
transactions[~transactions['UserID'].isin(users['UserID'])]
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 7              8      2014-04-24     NaN          2         3
# 8              9      2015-04-24     7.0          4         3

# %%
#Q 14 Join users to transactions, keeping only rows from transactions and users that match
# via UserID (inner join) Expected Output:

# %%
pd.merge(transactions,users,how='inner') #inner join
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              2      2011-05-26     3.0          4         1  Caroline
# 1              3      2011-06-16     3.0          3         1  Caroline
# 2              7      2013-12-30     3.0          4         1  Caroline
# 3             10      2016-05-08     3.0          4         4  Caroline
# 4              4      2012-08-26     1.0          2         3   Charles
# 5              5      2013-06-06     2.0          4         1     Pedro
# 6              6      2013-12-23     2.0          5         6     Pedro
#
#    Gender  Registered   Cancelled
# 0  female  2012-10-23  2016-06-07
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3  female  2012-10-23  2016-06-07
# 4    male  2012-12-21         NaN
# 5    male  2010-08-01  2010-08-08
# 6    male  2010-08-01  2010-08-08

# %%
# Q 15 Join users to transactions, displaying all matching rows AND all non-matching rows
# (full outer join)

# %%
transactions.merge(users,how='outer')#outer join
# Out:
#     TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0             1.0      2010-08-21     7.0        2.0       1.0       NaN
# 1             9.0      2015-04-24     7.0        4.0       3.0       NaN
# 2             2.0      2011-05-26     3.0        4.0       1.0  Caroline
# 3             3.0      2011-06-16     3.0        3.0       1.0  Caroline
# 4             7.0      2013-12-30     3.0        4.0       1.0  Caroline
# 5            10.0      2016-05-08     3.0        4.0       4.0  Caroline
# 6             4.0      2012-08-26     1.0        2.0       3.0   Charles
# 7             5.0      2013-06-06     2.0        4.0       1.0     Pedro
# 8             6.0      2013-12-23     2.0        5.0       6.0     Pedro
# 9             8.0      2014-04-24     NaN        2.0       3.0       NaN
# 10            NaN             NaN     4.0        NaN       NaN   Brielle
# 11            NaN             NaN     5.0        NaN       NaN  Benjamin
#
# ...

# %%
# Q 16 Determine which sessions occurred on the same day each user registered

# %%
pd.merge(sessions, users,left_on=['UserID','SessionDate'],right_on=['UserID','Registered'])
# Out:
#    SessionID SessionDate  UserID     User  Gender  Registered   Cancelled
# 0          2  2010-08-01       2    Pedro    male  2010-08-01  2010-08-08
# 1          9  2013-07-17       4  Brielle  female  2013-07-17         NaN

# %%
# Q 17 Build a dataset with every possible (UserID, ProductID) pair(Cross Join)

# %%
users['key']=1
products['key']=1
pd.merge(users,products,on='key',how='inner')[['UserID','ProductID']]
# Out:
#     UserID  ProductID
# 0        1          1
# 1        1          2
# 2        1          3
# 3        1          4
# 4        1          5
# 5        2          1
# 6        2          2
# 7        2          3
# 8        2          4
# 9        2          5
# 10       3          1
# 11       3          2
# 12       3          3
# 13       3          4
# 14       3          5
# 15       4          1
# 16       4          2
# 17       4          3
# 18       4          4
# 19       4          5
# 20       5          1
# 21       5          2
# 22       5          3
# 23       5          4
# 24       5          5

# %%
# Q 18. Determine how much quantity of each product was purchased by each user.

# %%
pd.merge(users,transactions , how='inner').groupby(['UserID','ProductID']).sum()  #Grouping o\pn the basis of the user and customer
# Out:
#                   key  TransactionID  Quantity
# UserID ProductID
# 1      2            1              4         3
# 2      4            1              5         1
#        5            1              6         6
# 3      3            1              3         1
#        4            3             19         6

# %%
dir(users)   #not the part of project it is just for takong help for the available pandas question
# Out:
# ['Cancelled',
#  'Gender',
#  'Registered',
#  'T',
#  'User',
#  'UserID',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
# ...

# %%
# Q 19 For each user, get each possible pair of pair transactions (TransactionID1,
# TransacationID2)

# %%
pd.merge(transactions, transactions,left_on='TransactionID',right_on='TransactionID') # self join
# Out:
#    TransactionID TransactionDate_x  UserID_x  ProductID_x  Quantity_x  \
# 0              1        2010-08-21       7.0            2           1
# 1              2        2011-05-26       3.0            4           1
# 2              3        2011-06-16       3.0            3           1
# 3              4        2012-08-26       1.0            2           3
# 4              5        2013-06-06       2.0            4           1
# 5              6        2013-12-23       2.0            5           6
# 6              7        2013-12-30       3.0            4           1
# 7              8        2014-04-24       NaN            2           3
# 8              9        2015-04-24       7.0            4           3
# 9             10        2016-05-08       3.0            4           4
#
#   TransactionDate_y  UserID_y  ProductID_y  Quantity_y
# 0        2010-08-21       7.0            2           1
# 1        2011-05-26       3.0            4           1
# ...

# %%
# Q 20. Join each user to his/her first occuring transaction in the transactions table

# %%
#using group by and than applyig the aggregation function first.
pd.merge(users, transactions.groupby('UserID').first().reset_index(),on='UserID')
# Out:
#    UserID      User  Gender  Registered   Cancelled  key  TransactionID  \
# 0       1   Charles    male  2012-12-21         NaN    1              4
# 1       2     Pedro    male  2010-08-01  2010-08-08    1              5
# 2       3  Caroline  female  2012-10-23  2016-06-07    1              2
#
#   TransactionDate  ProductID  Quantity
# 0      2012-08-26          2         3
# 1      2013-06-06          4         1
# 2      2011-05-26          4         1
